# %%
import subprocess
import itertools

# %%
lot = [
    (1, 3, 4),
    (1, 3, 4),
    (1, 3, 4),
    (1, 3, 4),
    (1, 3, 4),
]

# %%
list(itertools.chain(*lot))
# Out:
# [1, 3, 4, 1, 3, 4, 1, 3, 4, 1, 3, 4, 1, 3, 4]
